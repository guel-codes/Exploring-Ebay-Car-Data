# %% [markdown]
# # Exploring Ebay Car Dataset

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv('autos.csv', encoding='Latin-1')
autos = autos[0:100000] # original dataset was over 370,000 rows so I sampled 50,000
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
# dateCrawled            100000 non-null object
# name                   100000 non-null object
# seller                 100000 non-null object
# offerType              100000 non-null object
# price                  100000 non-null int64
# abtest                 100000 non-null object
# vehicleType            89901 non-null object
# yearOfRegistration     100000 non-null int64
# gearbox                94609 non-null object
# powerPS                100000 non-null int64
# model                  94508 non-null object
# kilometer              100000 non-null int64
# monthOfRegistration    100000 non-null int64
# fuelType               90946 non-null object
# brand                  100000 non-null object
# notRepairedDamage      80644 non-null object
# dateCreated            100000 non-null object
# nrOfPictures           100000 non-null int64
# postalCode             100000 non-null int64
# lastSeen               100000 non-null object
# dtypes: int64(7), object(13)
# memory usage: 15.3+ MB
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %% [markdown]
# # Clean Columns to be snakecase

# %%
autos.columns # get names of current columns to see which ones need changed
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'num_photos', 'postal_code',
       'last_seen']
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price ab_test vehicle_type  registration_year    gearbox  power_ps  model  \
# 0    480    test          NaN               1993    manuell         0   golf
# 1  18300    test        coupe               2011    manuell       190    NaN
# 2   9800    test          suv               2004  automatik       163  grand
# 3   1500    test   kleinwagen               2001    manuell        75   golf
# 4   3600    test   kleinwagen               2008    manuell        69  fabia
#
#    odometer  registration_month fuel_type       brand unrepaired_damage  \
# 0    150000                   0    benzin  volkswagen               NaN
# 1    125000                   5    diesel        audi                ja
# 2    125000                   8    diesel        jeep               NaN
# 3    150000                   6    benzin  volkswagen              nein
# 4     90000                   7    diesel       skoda              nein
#
#             ad_created  num_photos  postal_code            last_seen
# 0  2016-03-24 00:00:00           0        70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00           0        66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00           0        90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00           0        91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00           0        60437  2016-04-06 10:17:21

# %% [markdown]
# # Initial Data Exploration
# ## Examples of Columns that need cleaned:
#  - Any Columns with mostly one value are likely to be dropped.
#  - Any columns that need more investigation.
#  - Any examples of numeric data stored as text that needs to be cleaned.

# %%
autos.describe(include= 'all')
# Out:
#                date_crawled      name  seller offer_type         price  \
# count                100000    100000  100000     100000  1.000000e+05
# unique                92921     72510       2          2           NaN
# top     2016-03-07 15:48:46  BMW_318i  privat    Angebot           NaN
# freq                      4       183   99999      99998           NaN
# mean                    NaN       NaN     NaN        NaN  1.009095e+04
# std                     NaN       NaN     NaN        NaN  5.634880e+05
# min                     NaN       NaN     NaN        NaN  0.000000e+00
# 25%                     NaN       NaN     NaN        NaN  1.150000e+03
# 50%                     NaN       NaN     NaN        NaN  2.950000e+03
# 75%                     NaN       NaN     NaN        NaN  7.200000e+03
# max                     NaN       NaN     NaN        NaN  1.000000e+08
#
#        ab_test vehicle_type  registration_year  gearbox       power_ps  model  \
# count   100000        89901      100000.000000    94609  100000.000000  94508
# unique       2            8                NaN        2            NaN    248
# top       test    limousine                NaN  manuell            NaN   golf
# freq     51864        25827                NaN    74009            NaN   8048
# mean       NaN          NaN        2004.615250      NaN     114.600260    NaN
# std        NaN          NaN          94.080586      NaN     167.212918    NaN
# min        NaN          NaN        1000.000000      NaN       0.000000    NaN
# 25%        NaN          NaN        1999.000000      NaN      69.000000    NaN
# 50%        NaN          NaN        2003.000000      NaN     105.000000    NaN
# 75%        NaN          NaN        2008.000000      NaN     150.000000    NaN
# max        NaN          NaN        9999.000000      NaN   17932.000000    NaN
#
#              odometer  registration_month fuel_type       brand  \
# count   100000.000000       100000.000000     90946      100000
# unique            NaN                 NaN         7          40
# top               NaN                 NaN    benzin  volkswagen
# freq              NaN                 NaN     60132       21324
# mean    125432.800000            5.736830       NaN         NaN
# std      40203.126086            3.715986       NaN         NaN
# min       5000.000000            0.000000       NaN         NaN
# 25%     100000.000000            3.000000       NaN         NaN
# 50%     150000.000000            6.000000       NaN         NaN
# 75%     150000.000000            9.000000       NaN         NaN
# max     150000.000000           12.000000       NaN         NaN
#
#        unrepaired_damage           ad_created  num_photos    postal_code  \
# count              80644               100000    100000.0  100000.000000
# unique                 2                   87         NaN            NaN
# top                 nein  2016-04-03 00:00:00         NaN            NaN
# freq               70786                 3943         NaN            NaN
# mean                 NaN                  NaN         0.0   50827.250050
# std                  NaN                  NaN         0.0   25833.394784
# min                  NaN                  NaN         0.0    1067.000000
# 25%                  NaN                  NaN         0.0   30457.000000
# 50%                  NaN                  NaN         0.0   49549.000000
# 75%                  NaN                  NaN         0.0   71673.750000
# max                  NaN                  NaN         0.0   99998.000000
#
#                   last_seen
# count                100000
# unique                68019
# top     2016-04-07 14:56:13
# freq                     11
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# 99976  2016-03-23 13:42:51            BMW_X3_3.0d_Volllerdr_Xenon_Frontschden
# 99977  2016-03-30 01:58:06  Ford_C_Max_Ghia_Vollausstattung_Scheckheft_18_...
# 99978  2016-03-19 10:47:05                           Renault_Laguna_Grandtour
# 99979  2016-03-07 04:37:02                            Volkswagen_Scirocco_GT2
# 99980  2016-03-31 10:57:03                       Opel_Zafira_2.2_DTI_Elegance
# 99981  2016-03-08 18:40:39                         Ford_ECOSPORT_1.0_EcoBoost
# 99982  2016-03-27 21:46:39                                 MINI_Cooper_Cabrio
# 99983  2016-03-22 12:38:41                           Volkswagen_Caddy_2.0_SDI
# 99984  2016-03-19 14:51:57                                Mercedes_C180_Sport
# 99985  2016-03-06 16:25:24                                         BMW_320_Ci
# 99986  2016-03-08 17:37:03            Corsa_1.7_CDTI_COSMO_5_TueREN_SUPER_TOP
# 99987  2016-03-09 13:46:56                                Audi_A8_3.7_quattro
# 99988  2016-03-26 20:36:58                                   Bmw_325ci_Cabrio
# 99989  2016-03-22 22:44:51          Dodge_Dakota_Marklll_5.2_V8_LKW_Zulassung
# 99990  2016-03-15 17:06:21                           Seat_cupra_LPG_4x4_6gang
# 99991  2016-04-01 16:37:14                                   Seat_Ibiza_Sport
# 99992  2016-03-15 16:58:07                      Volkswagen_Golf_1.6_CL_Europe
# 99993  2016-03-07 14:54:17                               VW_Golf_Tuev_05/2017
# 99994  2016-03-07 21:46:09         Seat_Toledo_1.6_mit_Klima_Schiebedach_u.m.
# 99995  2016-04-04 17:37:50  Skoda_Octavia_1.6_Kombi_Ambiente__AHK_abn.__8x...
# 99996  2016-03-23 14:45:05            AUDI_A4_B5_1_8_Kombi__Automatik__Tuning
# 99997  2016-04-04 15:41:25                                     Renault_Megane
# 99998  2016-03-31 17:55:09                            !!!_Opel_Corsa_B_eco!!!
# 99999  2016-03-05 21:50:00          Mercedes_Benz_E_Klasse_220_CDI_Avantgarde
#
#        price  ab_test vehicle_type  registration_year    gearbox  power_ps  \
# 0        480     test          NaN               1993    manuell         0
# 1      18300     test        coupe               2011    manuell       190
# 2       9800     test          suv               2004  automatik       163
# 3       1500     test   kleinwagen               2001    manuell        75
# 4       3600     test   kleinwagen               2008    manuell        69
# 5        650     test    limousine               1995    manuell       102
# 6       2200     test       cabrio               2004    manuell       109
# 7          0     test    limousine               1980    manuell        50
# 8      14500  control          bus               2014    manuell       125
# 9        999     test   kleinwagen               1998    manuell       101
# 10      2000  control    limousine               2004    manuell       105
# 11      2799  control        kombi               2005    manuell       140
# 12       999  control        kombi               1995    manuell       115
# 13      2500  control        kombi               2004    manuell       131
# 14     17999  control          suv               2011    manuell       190
# 15       450     test   kleinwagen               1910        NaN         0
# 16       300     test          NaN               2016        NaN        60
# 17      1750  control   kleinwagen               2004  automatik        75
# 18      7550     test          bus               2007    manuell       136
# 19      1850     test          bus               2004    manuell       102
# 20     10400  control        coupe               2009    manuell       160
# 21      3699     test    limousine               2002  automatik       231
# 22      2900     test          NaN               2018    manuell        90
# 23       450     test   kleinwagen               1997    manuell        50
# 24       500     test    limousine               1990    manuell       118
# 25      2500  control        kombi               2002  automatik       193
# 26      5555  control          NaN               2017    manuell       125
# 27      6900     test    limousine               2008    manuell        99
# 28      1990     test          bus               1981    manuell        50
# 29       690     test   kleinwagen               2003    manuell        60
# ...      ...      ...          ...                ...        ...       ...
# 99970   1199  control   kleinwagen               2002    manuell        60
# 99971   2749  control   kleinwagen               2009    manuell        65
# 99972   1190  control   kleinwagen               1999    manuell        65
# 99973   6000     test    limousine               2010  automatik       160
# 99974    600     test    limousine               1993    manuell       116
# 99975   2990     test          bus               1999    manuell       109
# 99976   3500     test    limousine               2004  automatik       204
# 99977   4990     test          bus               2004    manuell       136
# 99978    650     test        kombi               1998    manuell        83
# 99979   1600     test        coupe               1990  automatik         0
# 99980   1200  control          bus               2003    manuell       125
# 99981  14600     test          suv               2015    manuell       125
# 99982   7500     test       cabrio               2005    manuell       116
# 99983   1799  control          bus               2005    manuell        69
# 99984      0     test    limousine               1998  automatik       122
# 99985   3000     test       cabrio               2002    manuell       170
# 99986   2800  control    limousine               2009    manuell       125
# 99987   7900  control    limousine               2003  automatik       280
# 99988   6799  control       cabrio               2002    manuell       193
# 99989   5999  control       andere               1995  automatik       243
# 99990   2999  control        coupe               2001    manuell       204
# 99991   6900  control   kleinwagen               2009    manuell        86
# 99992    600  control    limousine               1993    manuell        75
# 99993   1350  control    limousine               1998        NaN         0
# 99994   1850  control    limousine               2001    manuell       101
# 99995   2100     test        kombi               2000    manuell       102
# 99996   3499     test        kombi               1999  automatik       125
# 99997   2000     test          NaN               2005    manuell         0
# 99998   1000  control   kleinwagen               1997    manuell         0
# 99999   2999     test    limousine               1999    manuell       143
#
#              model  odometer  registration_month fuel_type           brand  \
# 0             golf    150000                   0    benzin      volkswagen
# 1              NaN    125000                   5    diesel            audi
# 2            grand    125000                   8    diesel            jeep
# 3             golf    150000                   6    benzin      volkswagen
# 4            fabia     90000                   7    diesel           skoda
# 5              3er    150000                  10    benzin             bmw
# 6          2_reihe    150000                   8    benzin         peugeot
# 7           andere     40000                   7    benzin      volkswagen
# 8            c_max     30000                   8    benzin            ford
# 9             golf    150000                   0       NaN      volkswagen
# 10         3_reihe    150000                  12    benzin           mazda
# 11          passat    150000                  12    diesel      volkswagen
# 12          passat    150000                  11    benzin      volkswagen
# 13          passat    150000                   2       NaN      volkswagen
# 14          navara     70000                   3    diesel          nissan
# 15              ka      5000                   0    benzin            ford
# 16            polo    150000                   0    benzin      volkswagen
# 17          twingo    150000                   2    benzin         renault
# 18           c_max    150000                   6    diesel            ford
# 19        a_klasse    150000                   1    benzin   mercedes_benz
# 20        scirocco    100000                   4    benzin      volkswagen
# 21             5er    150000                   7    benzin             bmw
# 22          meriva    150000                   5    benzin            opel
# 23           arosa    150000                   5    benzin            seat
# 24          andere    150000                  10    benzin   mercedes_benz
# 25             5er    150000                   9    diesel             bmw
# 26              c4    125000                   4       NaN         citroen
# 27           civic     60000                  11    benzin           honda
# 28     transporter      5000                   1    benzin      volkswagen
# 29           punto    150000                   3    benzin            fiat
 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos["odometer_km"].replace({"km",""})
autos["odometer_km"].replace({",",""})
autos["odometer_km"].astype(int)
                          
autos["odometer_km"].head()
# Out:
# 0    150000
# 1    125000
# 2    125000
# 3    150000
# 4     90000
# Name: odometer_km, dtype: int64

# %% [markdown]
# # Continuing to look into the odometer_km and price columns
# ## Things we will look for:
#   - Max & min of the columns
#   - look at the uniques values
#   - remove any outliers using df[df["col"].between(x,y)]

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    64564
# 125000    10311
# 100000     4325
# 90000      3295
# 80000      3032
# 70000      2674
# 60000      2369
# 50000      2084
# 5000       1863
# 40000      1730
# 30000      1664
# 20000      1535
# 10000       554
# Name: odometer_km, dtype: int64

# %%
print(autos["price"].unique().shape) 
print(autos["price"].describe())
autos["price"].value_counts().head(20).sort_index(ascending = True)
# Out:
# (3231,)
# count    1.000000e+05
# mean     1.009095e+04
# std      5.634880e+05
# min      0.000000e+00
# 25%      1.150000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
# 0       2917
# 500     1519
# 600     1009
# 650      805
# 700      797
# 750      873
# 800     1053
# 850      779
# 900      764
# 950      778
# 999      939
# 1000    1240
# 1100     773
# 1200    1235
# 1500    1464
# 1800     788
# 2000     981
# 2500    1167
# 3500     997
# 4500     785
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending = False).head(20)
# Out:
# 99999999    3
# 27322222    1
# 12345678    2
# 11111111    3
# 10000000    1
# 9999999     2
# 2995000     1
# 2795000     1
# 1250000     2
# 1111111     1
# 1000000     3
# 999999      2
# 911911      1
# 820000      1
# 600000      1
# 579000      1
# 500000      1
# 420000      1
# 395000      1
# 350000      1
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending = True).head(20)
# Out:
# 0     2917
# 1      308
# 2        3
# 3        2
# 4        1
# 5        8
# 7        1
# 8        4
# 9        1
# 10      21
# 11       1
# 12       3
# 13       2
# 14       2
# 15       6
# 16       1
# 17       3
# 20      14
# 24       1
# 25       8
# Name: price, dtype: int64

# %%
#This will keep items that are within $1 and $200,000. 
#Leaving out the 2,917 items that have a price listed as free.
autos = autos[autos["price"].between(1,200000)]

# %%
autos["price"].describe()
# Out:
# count     97042.000000
# mean       5894.340038
# std        8429.487913
# min           1.000000
# 25%        1250.000000
# 50%        3000.000000
# 75%        7499.000000
# max      199900.000000
# Name: price, dtype: float64

# %% [markdown]
# # Exploring the Date Columns
# Below is a list of columns that hold dates.
# - date_crawled
# - registration_month
# - registration_year
# - ad_created
# - last_seen

# %%
# data_crawled, last_seen and ad_created columns are all strings that need converted to float.
# let's explore the columns
autos[['date_crawled','ad_created','last_seen']].head()
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-24 11:52:17  2016-03-24 00:00:00  2016-04-07 03:16:57
# 1  2016-03-24 10:58:45  2016-03-24 00:00:00  2016-04-07 01:46:50
# 2  2016-03-14 12:52:21  2016-03-14 00:00:00  2016-04-05 12:47:46
# 3  2016-03-17 16:54:04  2016-03-17 00:00:00  2016-03-17 17:40:17
# 4  2016-03-31 17:25:20  2016-03-31 00:00:00  2016-04-06 10:17:21

# %%
(autos["date_crawled"].str[:10]
 .value_counts(normalize=True, dropna=False)
 .sort_index().sort_values())
# Out:
# 2016-04-07    0.001608
# 2016-04-06    0.003019
# 2016-03-18    0.013262
# 2016-04-05    0.013273
# 2016-03-06    0.014581
# 2016-03-13    0.015179
# 2016-03-26    0.016148
# 2016-03-15    0.016302
# 2016-03-16    0.016477
# 2016-03-27    0.016776
# 2016-03-23    0.018209
# 2016-03-25    0.018837
# 2016-03-24    0.019198
# 2016-03-21    0.019662
# 2016-03-22    0.019971
# 2016-03-20    0.020239
# 2016-03-28    0.021918
# 2016-03-12    0.022866
# 2016-03-29    0.023114
# 2016-03-30    0.023279
# 2016-04-01    0.023598
# 2016-03-31    0.024165
# 2016-04-03    0.025020
# 2016-04-02    0.025298
# 2016-04-04    0.026020
# 2016-03-17    0.028761
# 2016-04-05    0.127574
# 2016-04-07    0.132067
# 2016-04-06    0.219359
# Name: last_seen, dtype: float64

# %%
autos["registration_year"].describe()
# Out:
# count    97042.000000
# mean      2004.620752
# std         88.157584
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# # Registration year issues
#  - The lowest registration year is 1000.
#  - The largest registration year is 9999.
#
#  - Find percentage of dates that fall outside of acceptable dates.
#  - Exclude the dates outside of the acceptable limits.

# %%
# This will get the percentage of dates outside of the dates that are possible for 
((~autos["registration_year"].between(1900,2016)).sum() / autos.shape[0]) * 100
# Out:
# 4.029653634012896

# %%
autos = autos[autos["registration_year"].between(1900,2016)]
autos["registration_year"].value_counts(normalize=True).head(20)
# Out:
# 2000    0.071927
# 2005    0.068343
# 1999    0.068123
# 2006    0.062780
# 2001    0.062017
# 2003    0.060791
# 2004    0.059207
# 2002    0.058467
# 2007    0.054165
# 1998    0.053726
# 2008    0.050407
# 2009    0.048117
# 1997    0.043792
# 2010    0.038357
# 2011    0.037305
# 1996    0.032344
# 2012    0.029153
# 1995    0.028655
# 2016    0.028366
# 2013    0.019809
# Name: registration_year, dtype: float64

# %% [markdown]
# It appears a majority of the cars were registered in the past 20 years.

# %%
autos["brand"].value_counts(normalize=True)
# Out:
# volkswagen        0.205132
# bmw               0.111037
# opel              0.107880
# mercedes_benz     0.092974
# audi              0.089158
# ford              0.071153
# renault           0.050500
# peugeot           0.031870
# fiat              0.026181
# seat              0.020549
# skoda             0.017103
# mazda             0.016224
# smart             0.015380
# citroen           0.014698
# nissan            0.013946
# toyota            0.012790
# hyundai           0.010731
# mini              0.009980
# volvo             0.008407
# mitsubishi        0.008303
# kia               0.007794
# honda             0.006765
# suzuki            0.006499
# sonstige_autos    0.006302
# alfa_romeo        0.006164
# porsche           0.005354
# chevrolet         0.004429
# chrysler          0.003828
# dacia             0.002729
# daihatsu          0.002532
# land_rover        0.002243
# subaru            0.001989
# jeep              0.001966
# jaguar            0.001596
# daewoo            0.001492
# lancia            0.001341
# saab              0.001260
# rover             0.001133
# lada              0.000532
# trabant           0.000058
# Name: brand, dtype: float64

# %% [markdown]
# It looks like the top 4 brands are all German brands. This makes me want to look into the original dataset and see where it originated. If you refer to the beginning where I changes the column names to snake_case. You can see that some of the information looks european (ex. odometer is in KM).
#
# VW is the second largest car manufacturer in the world. The thing that doesn't make sense to me is how low Toyota appears on the list.
#
# Toyota is the largest car manufacturer in the work so you would expect them to be higher in the list. However, it is extremely important to remember that we are looking at Ebay Sales Data and since Toyota are known to be very reliable it might be less likely that people want to sell their Toyotas on Ebay.
#
# Toyota, being the largest manufacturer, might also offer better trade-in values for used cars at their dealerships due to their known reliablity.

# %%
brand_counts = autos["brand"].value_counts(normalize = True)
common_brands = brand_counts[brand_counts > .01].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat', 'skoda', 'mazda', 'smart', 'citroen',
#        'nissan', 'toyota', 'hyundai'],
#       dtype='object')

# %%
brand_mean_price = {}
for brand in common_brands:
    car_brand = autos[autos["brand"] == brand]
    mean_price = car_brand["price"].mean()
    brand_mean_price[brand] = int(mean_price)
    
brand_mean_price
# Out:
# {'volkswagen': 5653,
#  'bmw': 8745,
#  'opel': 3004,
#  'mercedes_benz': 8895,
#  'audi': 9650,
#  'ford': 3622,
#  'renault': 2456,
#  'peugeot': 3276,
#  'fiat': 2818,
#  'seat': 4784,
#  'skoda': 6631,
#  'mazda': 4346,
#  'smart': 3674,
#  'citroen': 3648,
#  'nissan': 4559,
#  'toyota': 5222,
#  'hyundai': 5666}

# %%
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=["mean_price"]):
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=["mean_price"])

# %% [markdown]
# Out of the top brands BMW, Mercedes-Benz, and Audi prices reflect that they are luxury brands. Which surprises me about Skoda, because it is almost the price of BMW but I have never heard of it.

# %%
brand_mean_mileage = {}

for brand in common_brands:
    car_brand = autos[autos["brand"] == brand]
    mean_mileage = car_brand["odometer_km"].mean()
    brand_mean_mileage[brand] = int(mean_mileage)
    
mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_price).sort_values(ascending=False)

# %%
brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info
# Out:
#                mean_mileage
# bmw                  132279
# mercedes_benz        129361
# opel                 129206
# audi                 128728
# volkswagen           128143
# renault              127860
# peugeot              124473
# ford                 124224
# mazda                123496
# citroen              121219
# nissan               119937
# seat                 119760
# toyota               117549
# fiat                 117305
# skoda                112160
# hyundai              104251
# smart                 99560

# %%
brand_info["mean_price"] = mean_prices
brand_info
# Out:
#                mean_mileage  mean_price
# bmw                  132279        8745
# mercedes_benz        129361        8895
# opel                 129206        3004
# audi                 128728        9650
# volkswagen           128143        5653
# renault              127860        2456
# peugeot              124473        3276
# ford                 124224        3622
# mazda                123496        4346
# citroen              121219        3648
# nissan               119937        4559
# seat                 119760        4784
# toyota               117549        5222
# fiat                 117305        2818
# skoda                112160        6631
# hyundai              104251        5666
# smart                 99560        3674

# %% [markdown]
# # Next Steps
# ## Data cleaning & Analysis next steps:
#  - Identify categorical data that uses german words, translate them and map the values to their english counterparts
#  - Convert the dates to be uniform numeric data, so "2016-03-21" becomes the integer 20160321.
#  - See if there are particular keywords in the name column that you can extract as new columns
#  - Find the most common brand/model combinations
#  - Split the odometer_km into groups, and use aggregation to see if average prices follows any patterns based on the milage.
#  - How much cheaper are cars with damage than their non-damaged counterparts?
